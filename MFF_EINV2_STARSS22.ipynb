# %%
# !pip install gdown
# !gdown --id 19KQvwHCCOzgrCN5KyK1lW7sD2CxjYvxX --output starss22_dataset
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=19KQvwHCCOzgrCN5KyK1lW7sD2CxjYvxX
# From (redirected): https://drive.google.com/uc?id=19KQvwHCCOzgrCN5KyK1lW7sD2CxjYvxX&confirm=t&uuid=37b1cd6f-b1db-4085-823e-0cc66a945f07
# To: /kaggle/working/starss22_dataset
# 100%|██████████████████████████████████████| 6.08G/6.08G [01:29<00:00, 68.0MB/s]

# %%
# !unzip starss22_dataset -d starss22_unzipped
# Out:
# Archive:  starss22_dataset
#    creating: starss22_unzipped/STARSS22/
#    creating: starss22_unzipped/STARSS22/foa_dev/
#    creating: starss22_unzipped/STARSS22/foa_dev/foa_dev/
#    creating: starss22_unzipped/STARSS22/foa_dev/foa_dev/dev-test-sony/
#   inflating: starss22_unzipped/STARSS22/foa_dev/foa_dev/dev-test-sony/fold4_room23_mix001.wav
#   inflating: starss22_unzipped/STARSS22/foa_dev/foa_dev/dev-test-sony/fold4_room23_mix002.wav
#   inflating: starss22_unzipped/STARSS22/foa_dev/foa_dev/dev-test-sony/fold4_room23_mix003.wav
#   inflating: starss22_unzipped/STARSS22/foa_dev/foa_dev/dev-test-sony/fold4_room23_mix004.wav
#   inflating: starss22_unzipped/STARSS22/foa_dev/foa_dev/dev-test-sony/fold4_room23_mix005.wav
#   inflating: starss22_unzipped/STARSS22/foa_dev/foa_dev/dev-test-sony/fold4_room23_mix006.wav
#   inflating: starss22_unzipped/STARSS22/foa_dev/foa_dev/dev-test-sony/fold4_room23_mix007.wav
# ...

# %%
# !rm starss22_dataset

# %%
# !mkdir -p STARSS22

# %%
# !mv /kaggle/working/starss22_unzipped/STARSS22/foa_dev/* /kaggle/working/STARSS22

# %%
# !mv /kaggle/working/starss22_unzipped/STARSS22/foa_eval/* /kaggle/working/STARSS22

# %%
# !mv /kaggle/working/starss22_unzipped/STARSS22/metadata_dev/* /kaggle/working/STARSS22

# %%
rm -rf /kaggle/working/starss22_unzipped

# %%
# !mkdir -p dataset

# %%
# !mv /kaggle/working/STARSS22 /kaggle/working/dataset

# %%
# !git clone https://github.com/Arnav-Sharmaa/MFF-EINV2.git
# Out:
# Cloning into 'MFF-EINV2'...
# remote: Enumerating objects: 219, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 219 (delta 68), reused 197 (delta 49), pack-reused 0 (from 0)
# Receiving objects: 100% (219/219), 352.30 KiB | 8.59 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
cd MFF-EINV2
# Out:
# /kaggle/working/MFF-EINV2

# %%
# !mv /kaggle/working/dataset /kaggle/working/MFF-EINV2

# %%
pip install ruamel.yaml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 18.6 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install torch torchaudio librosa numpy pandas soundfile pyyaml scikit-learn matplotlib tqdm h5py resampy joblib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.0 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 92.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
# ...

# %%
# !bash /kaggle/working/MFF-EINV2/scripts/preprocess.sh
# Out:
# 2025-04-14 17:49:09.050962: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744652949.236500     125 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744652949.288060     125 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Args:
#      config_file               -> ./configs/ein_seld/seld.yaml
#      dataset                   -> STARSS22
#      mode                      -> preprocess
#      preproc_mode              -> extract_data
#      dataset_type              -> dev
#      num_workers               -> 4
#      no_cuda                   -> False
# Cfg:
# ...

# %%
# !bash /kaggle/working/MFF-EINV2/scripts/train.sh
# Out:
# Starting training with GPU:0
# Mon Apr 14 17:51:57 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !bash /kaggle/working/MFF-EINV2/scripts/infer.sh
# Out:
# 2025-04-14 20:04:58.810004: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744661098.833003     718 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744661098.840286     718 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Args:
#      config_file               -> ./configs/ein_seld/seld.yaml
#      dataset                   -> STARSS22
#      mode                      -> infer
#      num_workers               -> 4
#      no_cuda                   -> False
# Cfg:
#      method: ein_seld
#      dataset: dcase2022task3 # dcase2022task3 or dcase2023task3
# ...

# %%
# !python3 code/compute_seld_metrics.py --dataset='STARSS22'
# Out:
# #### Classwise results on unseen test data ####
# Class	ER	F	LE	LR	SELD_score
# 0	0.872	0.126	43.055	0.450	0.634
# 1	0.872	0.352	27.157	0.560	0.527
# 2	0.872	0.135	22.281	0.300	0.640
# 3	0.872	0.000	37.277	0.039	0.760
# 4	0.872	0.020	52.375	0.139	0.751
# 5	0.872	0.122	39.174	0.733	0.558
# 6	0.872	0.127	25.530	0.172	0.679
# 7	0.872	0.000	40.595	0.054	0.761
# 8	0.872	0.152	48.697	0.609	0.595
# 9	0.872	0.342	15.970	0.361	0.565
# 10	0.872	0.270	19.600	0.500	0.553
# 11	0.872	0.014	56.348	0.348	0.706
# 12	0.872	0.000	180.000	0.000	0.968
# ######## MACRO ########
# SELD score (early stopping metric): 0.669
# SED metrics: Error rate: 0.872, F-score:12.8
# DOA metrics: Localization error: 46.8, Localization Recall: 32.8
# ######## MICRO ########
# SELD score (early stopping metric): 0.583
# SED metrics: Error rate: 0.872, F-score:21.4
# DOA metrics: Localization error: 36.3, Localization Recall: 52.9
