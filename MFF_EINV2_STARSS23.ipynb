# %%
# !git pull https://github.com/Arnav-Sharmaa/MFF-EINV2.git
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 2), reused 5 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 374 bytes | 374.00 KiB/s, done.
# From https://github.com/Arnav-Sharmaa/MFF-EINV2
#  * branch            HEAD       -> FETCH_HEAD
# Updating b48e18c..fd0a8e1
# Fast-forward
#  configs/ein_seld/seld.yaml | 6 +++---
#  1 file changed, 3 insertions(+), 3 deletions(-)

# %%
# !git remote -v
# Out:
# origin	https://github.com/Arnav-Sharmaa/MFF-EINV2.git (fetch)
# origin	https://github.com/Arnav-Sharmaa/MFF-EINV2.git (push)

# %%
ls
# Out:
# MFF-EINV2/  state.db

# %%
cd MFF-EINV2
# Out:
# /kaggle/working/MFF-EINV2

# %%
# !mkdir -p MFF-EINV2/dataset

# %%
# !pip install gdown

# %%
# !gdown --id 1xWmqbl8It7vIkDB2vUJO6EFdDMmW3K4M --output starss23.zip

# %%
# !unzip starss23.zip -d starss23_unzipped

# %%
# !rm starss23.zip

# %%
# !mkdir -p STARSS23

# %%
# !unzip /kaggle/working/starss23_unzipped/STARSS23/foa_dev.zip -d STARSS23

# %%
# !unzip /kaggle/working/starss23_unzipped/STARSS23/metadata_dev.zip -d STARSS23

# %%
# !mv /kaggle/working/starss23_unzipped/STARSS23/metadata_dev/* STARSS23

# %%
# !rm -rf starss23_unzipped

# %%
# !pip install torch torchaudio librosa numpy pandas soundfile pyyaml scikit-learn matplotlib tqdm h5py resampy joblib

# %%
# !mv /kaggle/working/STARSS23 MFF-EINV2/dataset

# %%
# !mv /kaggle/working/MFF-EINV2/dataset/foa_dev /kaggle/working/MFF-EINV2/dataset/STARSS23

# %%
cd MFF-EINV2
# Out:
# /kaggle/working/MFF-EINV2

# %%
ls
# Out:
# code/     dataset/          images/  README.md
# configs/  environment.yaml  LICENSE  scripts/

# %%
pip install ruamel.yaml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 28.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
rm -rf /kaggle/working/MFF-EINV2/_hdf5

# %%
# !bash /kaggle/working/MFF-EINV2/scripts/preprocess.sh
# Out:
# 2025-04-14 13:35:22.417033: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744637722.438726    1042 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744637722.445505    1042 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Args:
#      config_file               -> ./configs/ein_seld/seld.yaml
#      dataset                   -> STARSS23
#      mode                      -> preprocess
#      preproc_mode              -> extract_data
#      dataset_type              -> dev
#      num_workers               -> 4
#      no_cuda                   -> False
# Cfg:
# ...

# %%
rm -rf /kaggle/working/MFF-EINV2/results

# %%
# !bash /kaggle/working/MFF-EINV2/scripts/train.sh
# Out:
# Starting training with GPU:0
# Mon Apr 14 17:24:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !bash /kaggle/working/MFF-EINV2/scripts/infer.sh
# Out:
# 2025-04-14 20:51:35.233701: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744663895.256384     598 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744663895.263214     598 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Args:
#      config_file               -> ./configs/ein_seld/seld.yaml
#      dataset                   -> STARSS22
#      mode                      -> infer
#      num_workers               -> 4
#      no_cuda                   -> False
# Cfg:
#      method: ein_seld
#      dataset: dcase2023task3 # dcase2022task3 or dcase2023task3
# ...

# %%
# !python3 code/compute_seld_metrics.py --dataset='STARSS23'
# Out:
# #### Classwise results on unseen test data ####
# Class	ER	F	LE	LR	SELD_score
# 0	0.844	0.273	35.613	0.589	0.545
# 1	0.844	0.308	28.266	0.589	0.526
# 2	0.844	0.032	45.082	0.136	0.732
# 3	0.844	0.010	58.555	0.225	0.734
# 4	0.844	0.030	41.124	0.063	0.745
# 5	0.844	0.184	27.999	0.749	0.517
# 6	0.844	0.007	19.291	0.011	0.733
# 7	0.844	0.022	34.226	0.026	0.747
# 8	0.844	0.197	42.522	0.579	0.576
# 9	0.844	0.086	38.545	0.327	0.661
# 10	0.844	0.282	14.180	0.240	0.600
# 11	0.844	0.069	15.579	0.111	0.688
# 12	0.844	0.000	180.000	0.000	0.961
# ######## MACRO ########
# SELD score (early stopping metric): 0.674
# SED metrics: Error rate: 0.844, F-score:11.5
# DOA metrics: Localization error: 44.7, Localization Recall: 28.0
# ######## MICRO ########
# SELD score (early stopping metric): 0.578
# SED metrics: Error rate: 0.844, F-score:21.2
# DOA metrics: Localization error: 33.9, Localization Recall: 50.7
